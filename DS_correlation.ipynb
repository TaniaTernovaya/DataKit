# %% [markdown]
# 1. ВСТУПЛЕНИЕ
# Часто разведывательный анализ данных во многих проектах моделирование предусматривает обледование корреляции среди предсказателей и целевой перемнной (x и y)
#
# Приянято говорить, что переменные x и y коррелирую положительно если высокие значение x сопровождаются высокими значениями y и отрицательно коррелируют в обратном случае

# %% [markdown]
# 2. КОЭФИЦИЕНТ КОРРЕЛЯЦИИ
# Это число от -1 до 1 дающее оценку корреляции связи между двумя переменными которые всегда находятся на одинаковой шкале измерения.
# КОЕЭФИЦИЕНТ КОРРЕЛЯЦИИ ПИРСОНА = произведение сумм отклоние первой переменной и второй от их срежних деленная на произвдение стандарнтных отклонений

# %%
import pandas as pd
telecom=pd.read_csv('/Users/tatanaternovaa/Documents/training-skills/table4.csv')
ax=telecom.plot.scatter(x='T',y='VZ')
